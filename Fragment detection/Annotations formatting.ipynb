# %%
from formatting import *

# Paths to new pictures and corresponding annotations
# before importing Sloth Json fix filepath in raw Json
pictures_path = 'CORAL FRAMES/'
sloth_json_path = 'Retraining.json'

# Don't change these
annotations_path = 'annotation/'
outputDir = "output/"

new_pictures_path = outputDir+"all_pictures/"

picture_subs = {True: outputDir+"train_pictures/",
                False: outputDir+"val_pictures/"}

# %%
# Converts Sloth JSON Format to Pascal VOC (one annotation file per image).
# Removes mentions to images that don't have any annotation.

add_new_annots(pictures_path, annotations_path, sloth_json_path, new_pictures_path)
# Out:
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H00200219.jpg
# CORAL FRAMES/SH001H00200219.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H00201114.jpg
# CORAL FRAMES/SH001H00201114.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H00211024.jpg
# CORAL FRAMES/SH001H00211024.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H00220214.jpg
# CORAL FRAMES/SH001H00220214.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H03211024.jpg
# CORAL FRAMES/SH001H03211024.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H03220214.jpg
# CORAL FRAMES/SH001H03220214.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H03220729.jpg
# CORAL FRAMES/SH001H03220729.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H03230116.jpg
# CORAL FRAMES/SH001H03230116.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H06200219.jpg
# CORAL FRAMES/SH001H06200219.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H00220729.jpg
# CORAL FRAMES/SH001H00220729.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H00230116.jpg
# CORAL FRAMES/SH001H00230116.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H06201114.jpg
# CORAL FRAMES/SH001H06201114.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H03201114.jpg
# CORAL FRAMES/SH001H03201114.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H03210421.jpg
# CORAL FRAMES/SH001H03210421.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H00210421.jpg
# CORAL FRAMES/SH001H00210421.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H03200219.jpg
# CORAL FRAMES/SH001H03200219.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H06220214.jpg
# CORAL FRAMES/SH001H06220214.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H06220729.jpg
# CORAL FRAMES/SH001H06220729.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H06230116.jpg
# CORAL FRAMES/SH001H06230116.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H09200219.jpg
# CORAL FRAMES/SH001H09200219.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H06210421.jpg
# CORAL FRAMES/SH001H06210421.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H06211024.jpg
# CORAL FRAMES/SH001H06211024.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H09201114.jpg
# CORAL FRAMES/SH001H09201114.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H00200219.jpg
# CORAL FRAMES/SH002H00200219.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H09210421.jpg
# CORAL FRAMES/SH001H09210421.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH001H09211024.jpg
# CORAL FRAMES/SH001H09211024.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H00201106.jpg
# CORAL FRAMES/SH002H00201106.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H00210421.jpg
# CORAL FRAMES/SH002H00210421.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H00211024.jpg
# CORAL FRAMES/SH002H00211024.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H00220216.jpg
# CORAL FRAMES/SH002H00220216.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H00220729.jpg
# CORAL FRAMES/SH002H00220729.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H00230114.jpg
# CORAL FRAMES/SH002H00230114.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H03200219.jpg
# CORAL FRAMES/SH002H03200219.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H03201106.jpg
# CORAL FRAMES/SH002H03201106.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H03210421.jpg
# CORAL FRAMES/SH002H03210421.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H03211024.jpg
# CORAL FRAMES/SH002H03211024.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H03220216.jpg
# CORAL FRAMES/SH002H03220216.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H03220729.jpg
# CORAL FRAMES/SH002H03220729.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H03230114.jpg
# CORAL FRAMES/SH002H03230114.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H06200219.jpg
# CORAL FRAMES/SH002H06200219.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002H06201106.jpg
# CORAL FRAMES/SH002H06201106.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH002
jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH047H09220807.jpg
# CORAL FRAMES/SH047H09220807.jpg
# ID
# DataRow ID
# Labeled Data
# Label
# Created By
# Project Name
# Created At
# Updated At
# Seconds to Label
# Seconds to Review
# Seconds to Create
# External ID
# Global Key
# Agreement
# Is Benchmark
# Benchmark Agreement
# Benchmark ID
# Dataset Name
# Reviews
# View Label
# Has Open Issues
# Skipped
# DataRow Workflow Info
# SH047H09230114.jpg
# CORAL FRAMES/SH047H09230114.jpg
# Added new annotations : 7830 annotations from 360 images

# %%
# Converts Pascal VOC to COCO JSON. Splits into training and validation subsets (one annotation file each).
# Copies images (only the ones with annotations) to subfolders.

create_coco(new_pictures_path, annotations_path, outputDir, picture_subs)
# Out:
# COCO annotations : Created 6147 annotations from 360 images

# %%
# %env PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python
# Out:
# env: PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python

# %%
# Creates TFRecords combining picture files and COCO annotations

#%run /usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/object_detection/dataset_tools/create_coco_tf_record.py \
# %run /home/vincent/.local/lib/python3.10/site-packages/object_detection/dataset_tools/create_coco_tf_record.py \
    --train_image_dir="/output/train_pictures" \
    --train_annotations_file="/output/COCO_train.json" \
    --output_dir="/output/TFRecords" \
    --val_image_dir="/output/val_pictures" \
    --val_annotations_file="/output/COCO_val.json"
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/lib/python3/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# /usr/lib/python3/dist-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'sudo.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_33670/3553352564.py in <module>
#       2
#       3 #%run /usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/object_detection/dataset_tools/create_coco_tf_record.py \
# ----> 4 get_ipython().run_line_magic('run', 'sudo /home/vincent/.local/lib/python3.10/site-packages/object_detection/dataset_tools/create_coco_tf_record.py      --train_image_dir="/output/train_pictures"      --train_annotations_file="/output/COCO_train.json"      --output_dir="/output/TFRecords"      --val_image_dir="/output/val_pictures"      --val_annotations_file="/output/COCO_val.json"')
#
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2362                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2363             with self.builtin_trap:
# -> 2364                 result = fn(*args, **kwargs)
#    2365             return result
#    2366
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /usr/lib/python3/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/lib/python3/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     723             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     724                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 725             raise Exception(msg)
#     726         except TypeError:
#     727             if fpath in sys.meta_path:
#
# Exception: File `'sudo.py'` not found.

# %% [markdown]
# # JSON files handling

# %%
# Merge JSON files for retraining?

import glob
import json
import os
result = []
for f in glob.glob('/home/mdc/Desktop/RunningFiles/JSON/*.json'):
    with open(f, "r") as infile:
        d = json.load(infile)
        result.append(d)

with open("/home/mdc/Desktop/Retraining/Retraining.json", "w") as outfile:
    json.dump(result, outfile, indent = 4)
